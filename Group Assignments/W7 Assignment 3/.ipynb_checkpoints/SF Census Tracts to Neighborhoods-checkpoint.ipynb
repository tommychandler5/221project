# %%
#importing libraries
import pandas as pd
import geopandas as gpd
import plotly.express as px

# %%
ct = gpd.read_file('data/SF2010_Neighborhoods_CTs.geojson')

# %%
ct.shape
# Out:
# (195, 6)

# %%
ct.head()
# Out:
#       shape_area             nhood tractce10        geoid      shape_len  \
# 0  3326589.16121      Hayes Valley    016400  06075016400  7589.67939621
# 1  3970258.84056  Western Addition    016100  06075016100   8525.8087554
# 2   3179072.0728  Western Addition    015900  06075015900  8000.96661904
# 3  3364564.73418         Japantown    015500  06075015500  12144.0167608
# 4   2515362.5151   Pacific Heights    015300  06075015300  6918.26802571
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.43247 37.77376, -122.4341...
# 1  MULTIPOLYGON (((-122.42354 37.77967, -122.4234...
# 2  MULTIPOLYGON (((-122.42469 37.78534, -122.4244...
# 3  MULTIPOLYGON (((-122.42469 37.78534, -122.4249...
# 4  MULTIPOLYGON (((-122.43492 37.78588, -122.4365...

# %%
ct.info
# Out:
# <bound method DataFrame.info of         shape_area                  nhood tractce10        geoid  \
# 0    3326589.16121           Hayes Valley    016400  06075016400
# 1    3970258.84056       Western Addition    016100  06075016100
# 2     3179072.0728       Western Addition    015900  06075015900
# 3    3364564.73418              Japantown    015500  06075015500
# 4     2515362.5151        Pacific Heights    015300  06075015300
# ..             ...                    ...       ...          ...
# 190  9188983.62573  Bayview Hunters Point    023400  06075023400
# 191  6851881.08692  Bayview Hunters Point    023300  06075023300
# 192  5389498.04303  Bayview Hunters Point    023102  06075023102
# 193  1743401.74561                Mission    022902  06075022902
# 194  3035836.45115                Mission    022803  06075022803
#
#          shape_len                                           geometry
# 0    7589.67939621  MULTIPOLYGON (((-122.43247 37.77376, -122.4341...
# 1     8525.8087554  MULTIPOLYGON (((-122.42354 37.77967, -122.4234...
# 2    8000.96661904  MULTIPOLYGON (((-122.42469 37.78534, -122.4244...
# 3    12144.0167608  MULTIPOLYGON (((-122.42469 37.78534, -122.4249...
# 4    6918.26802571  MULTIPOLYGON (((-122.43492 37.78588, -122.4365...
# ..             ...                                                ...
# 190  12565.4209534  MULTIPOLYGON (((-122.38452 37.72286, -122.3845...
# 191  11841.8133982  MULTIPOLYGON (((-122.39262 37.72928, -122.3927...
# 192  13510.2398324  MULTIPOLYGON (((-122.38156 37.73812, -122.3817...
# 193  6014.34262404  MULTIPOLYGON (((-122.40871 37.74835, -122.4088...
# 194  7534.62683191  MULTIPOLYGON (((-122.40745 37.75451, -122.4083...
#
# [195 rows x 6 columns]>

# %%
ct.columns = ['shape_area',
              'Neighborhood', 
              'Census Tract',
              'FIPS',
              'shape_len',
              'Geometry',]

# %%
ct.head()
# Out:
#       shape_area      Neighborhood Census Tract         FIPS      shape_len  \
# 0  3326589.16121      Hayes Valley       016400  06075016400  7589.67939621
# 1  3970258.84056  Western Addition       016100  06075016100   8525.8087554
# 2   3179072.0728  Western Addition       015900  06075015900  8000.96661904
# 3  3364564.73418         Japantown       015500  06075015500  12144.0167608
# 4   2515362.5151   Pacific Heights       015300  06075015300  6918.26802571
#
#                                             Geometry
# 0  MULTIPOLYGON (((-122.43247 37.77376, -122.4341...
# 1  MULTIPOLYGON (((-122.42354 37.77967, -122.4234...
# 2  MULTIPOLYGON (((-122.42469 37.78534, -122.4244...
# 3  MULTIPOLYGON (((-122.42469 37.78534, -122.4249...
# 4  MULTIPOLYGON (((-122.43492 37.78588, -122.4365...

# %%
ct['Neighborhood'].value_counts()
# Out:
# Sunset/Parkside                   14
# Mission                           13
# Bayview Hunters Point             11
# Outer Richmond                    10
# Excelsior                          8
# Tenderloin                         8
# Pacific Heights                    7
# Marina                             7
# Nob Hill                           7
# West of Twin Peaks                 7
# Inner Sunset                       6
# Noe Valley                         6
# Castro/Upper Market                6
# Western Addition                   6
# Bernal Heights                     6
# Oceanview/Merced/Ingleside         5
# Visitacion Valley                  5
# Hayes Valley                       5
# Inner Richmond                     4
# Haight Ashbury                     4
# Portola                            4
# Lakeshore                          4
# South of Market                    4
# Potrero Hill                       4
# Chinatown                          4
# Russian Hill                       4
# North Beach                        3
# Outer Mission                      3
# Lone Mountain/USF                  3
# Financial District/South Beach     3
# Glen Park                          2
# Presidio Heights                   2
# Twin Peaks                         2
# Japantown                          1
# Presidio                           1
# Mission Bay                        1
# Seacliff                           1
# McLaren Park                       1
# Lincoln Park                       1
# Golden Gate Park                   1
# Treasure Island                    1
# Name: Neighborhood, dtype: int64

# %%
ct.FIPS.head(3)
# Out:
# 0    06075016400
# 1    06075016100
# 2    06075015900
# Name: FIPS, dtype: object

# %%
import geopandas as gpd

# %%
# bring in the geojson file with census tracts
tracts=gpd.read_file('data/2010CTs.geojson')
# see what the data looks like
tracts.head()
# Out:
#   statefp10 mtfcc10 name10   intptlat10 awater10        namelsad10 funcstat10  \
# 0        06   G5020    165  +37.7741958        0  Census Tract 165          S
# 1        06   G5020    164  +37.7750995        0  Census Tract 164          S
# 2        06   G5020    163  +37.7760456        0  Census Tract 163          S
# 3        06   G5020    161  +37.7799831        0  Census Tract 161          S
# 4        06   G5020    160  +37.7823363        0  Census Tract 160          S
#
#   aland10      geoid10 tractce10    intptlon10 countyfp10  \
# 0  370459  06075016500    016500  -122.4477884        075
# 1  309097  06075016400    016400  -122.4369729        075
# 2  245867  06075016300    016300  -122.4295509        075
# 3  368901  06075016100    016100  -122.4286631        075
# 4  158236  06075016000    016000  -122.4224838        075
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...

# %%
tracts.shape
# Out:
# (197, 13)

# %%
tracts.plot

# %%
tracts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   statefp10   197 non-null    object
#  1   mtfcc10     197 non-null    object
#  2   name10      197 non-null    object
#  3   intptlat10  197 non-null    object
#  4   awater10    197 non-null    object
#  5   namelsad10  197 non-null    object
#  6   funcstat10  197 non-null    object
#  7   aland10     197 non-null    object
#  8   geoid10     197 non-null    object
#  9   tractce10   197 non-null    object
#  10  intptlon10  197 non-null    object
#  11  countyfp10  197 non-null    object
#  12  geometry    197 non-null    geometry
# dtypes: geometry(1), object(12)
# memory usage: 20.1+ KB

# %%
tracts = tracts[['tractce10','geometry']]
tracts.head()
# Out:
#   tractce10                                           geometry
# 0    016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1    016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2    016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3    016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4    016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...

# %%
# create a FIPS column before merging
tracts['FIPS'] ='06' + '075' + tracts['tractce10']

# %%
tracts.head()
# Out:
#   tractce10                                           geometry         FIPS
# 0    016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1    016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2    016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
# 3    016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...  06075016100
# 4    016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...  06075016000

# %%
# create a new dataframe based on the join, tracts is spatial data so must come first
nhoods=tracts.merge(ct,on="FIPS")

# %%
nhoods.head(5)
# Out:
#   tractce10                                           geometry         FIPS  \
# 0    016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1    016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2    016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
# 3    016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...  06075016100
# 4    016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...  06075016000
#
#       shape_area       Neighborhood Census Tract      shape_len  \
# 0  3986994.21363  Lone Mountain/USF       016500  9798.02524207
# 1  3326589.16121       Hayes Valley       016400  7589.67939621
# 2  2646081.50418       Hayes Valley       016300  6603.94140199
# 3  3970258.84056   Western Addition       016100   8525.8087554
# 4  1702990.14508   Western Addition       016000  5942.83554773
#
#                                             Geometry Color  Colors
# 0  MULTIPOLYGON (((-122.44092 37.77363, -122.4425...           NaN
# 1  MULTIPOLYGON (((-122.43247 37.77376, -122.4341...        purple
# 2  MULTIPOLYGON (((-122.42589 37.77460, -122.4275...        purple
# 3  MULTIPOLYGON (((-122.42354 37.77967, -122.4234...           red
# 4  MULTIPOLYGON (((-122.42119 37.78475, -122.4212...           red

# %%
# Defining the columns to keep (zoning district name, zoning use abbreviation, area, and geometry).
columns_to_keep = ['geometry',
                   'FIPS',
                   'Neighborhood']

# %%
nhoods2 = nhoods[columns_to_keep].copy()
nhoods2
# Out:
#                                               geometry         FIPS  \
# 0    MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1    MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2    MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
# 3    MULTIPOLYGON (((-122.42891 37.77804, -122.4291...  06075016100
# 4    MULTIPOLYGON (((-122.42042 37.78058, -122.4203...  06075016000
# ..                                                 ...          ...
# 190  MULTIPOLYGON (((-122.40716 37.77974, -122.4076...  06075017601
# 191  MULTIPOLYGON (((-122.44257 37.76593, -122.4423...  06075017000
# 192  MULTIPOLYGON (((-122.42695 37.76917, -122.4274...  06075016900
# 193  MULTIPOLYGON (((-122.43930 37.76817, -122.4401...  06075016700
# 194  MULTIPOLYGON (((-122.44055 37.77178, -122.4403...  06075016600
#
#             Neighborhood
# 0      Lone Mountain/USF
# 1           Hayes Valley
# 2           Hayes Valley
# 3       Western Addition
# 4       Western Addition
# ..                   ...
# 190      South of Market
# 191  Castro/Upper Market
# 192  Castro/Upper Market
# 193       Haight Ashbury
# 194       Haight Ashbury
#
# [195 rows x 3 columns]

# %%
nhoods2.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   geometry      195 non-null    geometry
#  1   FIPS          195 non-null    object
#  2   Neighborhood  195 non-null    object
# dtypes: geometry(1), object(2)
# memory usage: 6.1+ KB

# %%
nhoods2.head(3)
# Out:
#                                             geometry         FIPS  \
# 0  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
#
#         Neighborhood Color
# 0  Lone Mountain/USF
# 1       Hayes Valley
# 2       Hayes Valley

# %%
nhoods2.head(3)
# Out:
#                                             geometry         FIPS  \
# 0  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
#
#         Neighborhood   Color
# 0  Lone Mountain/USF     NaN
# 1       Hayes Valley  purple
# 2       Hayes Valley  purple

# %%
nhoods.plot(column='Neighborhood', missing_kwds={'color': 'lightgrey'})
# Out:
# <AxesSubplot: >

# %%
ax1 = nhoods2.plot(
        column='Neighborhood', 
        figsize=(12,10),
        cmap='PuBuGn',
        )
ax1.axis('off')
# Out:
# (-122.5467034, -122.2691646, 37.69699805, 37.940910949999996)

# %%
nhoods2.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e2c5b4fa399684091b66af3f88cf7eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e2c5b4fa399684091b66af3f88cf7eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e2c5b4fa399684091b66af3f88cf7eb = L.map(
#                 &quot;map_7e2c5b4fa399684091b66af3f88cf7eb&quot;,
#                 {
#                     center: [37.8189545, -122.407934],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7e2c5b4fa399684091b66af3f88cf7eb);
#
#
#
#
#
#             var tile_layer_8930f853d6b7f1e82f1501627400196f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e2c5b4fa399684091b66af3f88cf7eb);
#
#
#             map_7e2c5b4fa399684091b66af3f88cf7eb.fitBounds(
#                 [[37.708085, -122.534088], [37.929823999999996, -122.28178]],
#                 {}
#             );
#
#
#         function geo_json_7e6d76c809b98328d52834e46b474fbe_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7e6d76c809b98328d52834e46b474fbe_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7e6d76c809b98328d52834e46b474fbe_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_7e6d76c809b98328d52834e46b474fbe_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7e6d76c809b98328d52834e46b474fbe_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_7e6d76c809b98328d52834e46b474fbe.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7e6d76c809b98328d52834e46b474fbe_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7e6d76c809b98328d52834e46b474fbe = L.geoJson(null, {
#                 onEachFeature: geo_json_7e6d76c809b98328d52834e46b474fbe_onEachFeature,
#
#                 style: geo_json_7e6d76c809b98328d52834e46b474fbe_styler,
#                 pointToLayer: geo_json_7e6d76c809b98328d52834e46b474fbe_pointToLayer
#         });
#
#         function geo_json_7e6d76c809b98328d52834e46b474fbe_add (data) {
#             geo_json_7e6d76c809b98328d52834e46b474fbe
#                 .addData(data)
#                 .addTo(map_7e2c5b4fa399684091b66af3f88cf7eb);
#         }
#             geo_json_7e6d76c809b98328d52834e46b474fbe_add({&quot;bbox&quot;: [-122.534088, 37.708085, -122.28178, 37.929823999999996], &quot;features&quot;: [{&quot;bbox&quot;: [-122.454683, 37.77193, -122.440922, 37.776435], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-122.446471, 37.775802], [-122.44477999999998, 37.776016999999996], [-122.44313199999999, 37.776226], [-122.44148799999999, 37.776435], [-122.44130000000001, 37.775504999999995], [-122.44111000000001, 37.774567], [-122.440922, 37.773635], [-122.442565, 37.773424], [-122.444216, 37.773212], [-122.44590199999999, 37.772995], [-122.447497, 37.77279], [-122.44914299999999, 37.772579], [-122.450787, 37.77236800000001], [-122.452242, 37.772180999999996], [-1

# %%
nhoods2.explore(
     column="Neighborhood", # make choropleth based on "BoroName" column
     tooltip="Neighborhood", # show "BoroName" value in tooltip (on hover)
     popup=True, # show all values in popup (on click)
     tiles="CartoDB positron", # use "CartoDB positron" tiles
     cmap="Set2", # use "Set1" matplotlib colormap
     style_kwds=dict(color="white") # use black outline
    )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cd99371ec5701c7c1c3ddefe1520cfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Neighborhood&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Neighborhood&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66c2a5&#x27;&gt;&lt;/span&gt;Bayview Hunters Point&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66c2a5&#x27;&gt;&lt;/span&gt;Bernal Heights&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66c2a5&#x27;&gt;&lt;/span&gt;Castro/Upper Market&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66c2a5&#x27;&gt;&lt;/span&gt;Chinatown&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66c2a5&#x27;&gt;&lt;/span&gt;Excelsior&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fc8d62&#x27;&gt;&lt;/span&gt;Financial District/South Beach&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fc8d62&#x27;&gt;&lt;/span&gt;Glen Park&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fc8d62&#x27;&gt;&lt;/span&gt;Golden Gate Park&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fc8d62&#x27;&gt;&lt;/span&gt;Haight Ashbury&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#fc8d62&#x27;&gt;&lt;/span&gt;Hayes Valley&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8da0cb&#x27;&gt;&lt;/span&gt;Inner Richmond&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8da0cb&#x27;&gt;&lt;/span&gt;Inner Sunset&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8da0cb&#x27;&gt;&lt;/span&gt;Japantown&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8da0cb&#x27;&gt;&lt;/span&gt;Lakeshore&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8da0cb&#x27;&gt;&lt;/span&gt;Lincoln Park&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e78ac3&#x27;&gt;&lt;/span&gt;Lone Mountain/USF&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e78ac3&#x27;&gt;&lt;/span&gt;Marina&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e78ac3&#x27;&gt;&lt;/span&gt;McLaren Park&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e78ac3&#x27;&gt;&lt;/span&gt;Mission&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e78ac3&#x27;&gt;&lt;/span&gt;Mission Bay&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6d854&#x27;&gt;&lt;/span&gt;Nob Hill&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;backgroun

# %%
fig, ax = plt.subplots(figsize = (12,10)) 
nhoods2.plot(column = 'Neighborhood',legend=False,
  edgecolor='white',cmap = 'PuBuGn',ax=ax)
ax.axis('off')
plt.title('SF Neighborhoods by Census Tract')
# Out:
# Text(0.5, 1.0, 'SF Neighborhoods by Census Tract')
