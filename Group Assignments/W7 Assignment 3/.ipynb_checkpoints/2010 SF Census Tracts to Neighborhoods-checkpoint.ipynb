# %% [markdown]
# ## San Francisco: From (2010) Census Tracts to Neighborhoods
# ### Team Code & Cry
#
# In order to more effectively analyze and compare our data and findings, much of which was collected at the census tract level, we have decided to work at the neighborhood level. We believe that the neighborhood level is a significantly more accessible scale for storytelling and visualizations. In order to establish a share definition and list of neighborhoods, we used the [Analysis Neighborhoods data set](https://data.sfgov.org/Geographic-Locations-and-Boundaries/Analysis-Neighborhoods-2010-census-tracts-assigned/bwbp-wk3r) from DataSF to group all census tracts into assigned neighborhoods. These neighborhood boundaries and their respective census tracts were determined by the Department of Public Health and the Mayor's Office of Housing & Community Development, with support from the Planning Department.
#
# This data set includes 41 neighborhoods comprised of all 2010 census tracts, using common real estate and residents’ definitions for the purpose of providing consistency in the analysis and reporting of socio-economic, demographic, and environmental data. Note that these so-called 'analysis neighborhoods' are not codified in Planning Code nor Administrative Code, but they provide a consistent and shared understanding of neighborhood boundaries that will be applied throughout the entirety of our project - especially since our CalEnviroScreen data is from the 2015-2019 ACS and is based on 2010 census tracts.
# Let's check it out!

# %% [markdown]
# ### Understanding Neighborhood Boundaries

# %%
#importing libraries
import pandas as pd
import geopandas as gpd
import plotly.express as px

# %%
#pull in the Analysis Neighborhoods data set from DataSF
ct = gpd.read_file('data/SF2010_Neighborhoods_CTs.geojson')

# %%
ct.shape
# Out:
# (195, 6)

# %% [markdown]
# Looks like there are 195 census tracts in this file, all of which are assigned to one of the 41 established neighborhoods. Let's dig a bit deeper and see what the data looks like, i.e. what neighborhoods and census tracts are showing up within it:

# %%
ct.head()
# Out:
#       shape_area             nhood tractce10        geoid      shape_len  \
# 0  3326589.16121      Hayes Valley    016400  06075016400  7589.67939621
# 1  3970258.84056  Western Addition    016100  06075016100   8525.8087554
# 2   3179072.0728  Western Addition    015900  06075015900  8000.96661904
# 3  3364564.73418         Japantown    015500  06075015500  12144.0167608
# 4   2515362.5151   Pacific Heights    015300  06075015300  6918.26802571
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.43247 37.77376, -122.4341...
# 1  MULTIPOLYGON (((-122.42354 37.77967, -122.4234...
# 2  MULTIPOLYGON (((-122.42469 37.78534, -122.4244...
# 3  MULTIPOLYGON (((-122.42469 37.78534, -122.4249...
# 4  MULTIPOLYGON (((-122.43492 37.78588, -122.4365...

# %% [markdown]
# Great, this is the exact data we need in order to classify our other datasets by neighborhood, rather than by census tract. Let's clean this data set up a bit, though, by renaming some columns:

# %%
#renaming the six columns
ct.columns = ['Shape Area',
              'Neighborhood', 
              'Census Tract',
              'FIPS',
              'Shape Length',
              'Geometry',]

# %%
#checking that the above function worked
ct.head()
# Out:
#       Shape Area      Neighborhood Census Tract         FIPS   Shape Length  \
# 0  3326589.16121      Hayes Valley       016400  06075016400  7589.67939621
# 1  3970258.84056  Western Addition       016100  06075016100   8525.8087554
# 2   3179072.0728  Western Addition       015900  06075015900  8000.96661904
# 3  3364564.73418         Japantown       015500  06075015500  12144.0167608
# 4   2515362.5151   Pacific Heights       015300  06075015300  6918.26802571
#
#                                             Geometry
# 0  MULTIPOLYGON (((-122.43247 37.77376, -122.4341...
# 1  MULTIPOLYGON (((-122.42354 37.77967, -122.4234...
# 2  MULTIPOLYGON (((-122.42469 37.78534, -122.4244...
# 3  MULTIPOLYGON (((-122.42469 37.78534, -122.4249...
# 4  MULTIPOLYGON (((-122.43492 37.78588, -122.4365...

# %% [markdown]
# Perfect, now that our data is cleaned up a bit, let's see if we can learn more about the breakdown of how many census tracts fall within each of the 41 neighborhoods:

# %%
# getting a count on how many census tracts are in each of the 41 identified neighborhoods
ct['Neighborhood'].value_counts()
# Out:
# Sunset/Parkside                   14
# Mission                           13
# Bayview Hunters Point             11
# Outer Richmond                    10
# Excelsior                          8
# Tenderloin                         8
# Pacific Heights                    7
# Marina                             7
# Nob Hill                           7
# West of Twin Peaks                 7
# Inner Sunset                       6
# Noe Valley                         6
# Castro/Upper Market                6
# Western Addition                   6
# Bernal Heights                     6
# Oceanview/Merced/Ingleside         5
# Visitacion Valley                  5
# Hayes Valley                       5
# Inner Richmond                     4
# Haight Ashbury                     4
# Portola                            4
# Lakeshore                          4
# South of Market                    4
# Potrero Hill                       4
# Chinatown                          4
# ...

# %%
#quick stats on the neighborhood column
ct['Neighborhood'].describe()
# Out:
# count                 195
# unique                 41
# top       Sunset/Parkside
# freq                   14
# Name: Neighborhood, dtype: object

# %% [markdown]
# This is really interesting to see, and makes me excited to further visualize and map these neighborhoods.
#
# Next, we'll need to join this Analysis Neighborhoods data with our 2010 census tract spatial data. Then, we can begin the actual mapping and merging with other data sets.

# %% [markdown]
# ### Merging Analysis Neighborhoods with 2010 Census Tracts

# %%
import geopandas as gpd

# %%
# bring in the geojson file with census tracts
tracts=gpd.read_file('data/2010CTs.geojson')
# see what the data looks like
tracts.head()
# Out:
#   statefp10 mtfcc10 name10   intptlat10 awater10        namelsad10 funcstat10  \
# 0        06   G5020    165  +37.7741958        0  Census Tract 165          S
# 1        06   G5020    164  +37.7750995        0  Census Tract 164          S
# 2        06   G5020    163  +37.7760456        0  Census Tract 163          S
# 3        06   G5020    161  +37.7799831        0  Census Tract 161          S
# 4        06   G5020    160  +37.7823363        0  Census Tract 160          S
#
#   aland10      geoid10 tractce10    intptlon10 countyfp10  \
# 0  370459  06075016500    016500  -122.4477884        075
# 1  309097  06075016400    016400  -122.4369729        075
# 2  245867  06075016300    016300  -122.4295509        075
# 3  368901  06075016100    016100  -122.4286631        075
# 4  158236  06075016000    016000  -122.4224838        075
#
#                                             geometry
# 0  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# ...

# %%
#seeing how many rows and columns we're working with 
tracts.shape
# Out:
# (197, 13)

# %% [markdown]
# The analysis neighborhoods data set that we're working with includes 195 census tracts, so this is almost an exact match. Still, let's pull a bit more info on this data set before merging the two:

# %%
tracts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   statefp10   197 non-null    object
#  1   mtfcc10     197 non-null    object
#  2   name10      197 non-null    object
#  3   intptlat10  197 non-null    object
#  4   awater10    197 non-null    object
#  5   namelsad10  197 non-null    object
#  6   funcstat10  197 non-null    object
#  7   aland10     197 non-null    object
#  8   geoid10     197 non-null    object
#  9   tractce10   197 non-null    object
#  10  intptlon10  197 non-null    object
#  11  countyfp10  197 non-null    object
#  12  geometry    197 non-null    geometry
# dtypes: geometry(1), object(12)
# memory usage: 20.1+ KB

# %% [markdown]
# Looking at this list of columns, we really only need the census tract number (tractce10) and geometry columns in order to merge the two data sets. Let's move forward with doing so:

# %%
#keeping just two of the columns
tracts = tracts[['tractce10','geometry']]
tracts.head()
# Out:
#   tractce10                                           geometry
# 0    016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...
# 1    016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...
# 2    016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...
# 3    016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...
# 4    016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...

# %% [markdown]
# We have the census tract number, but we need a full FIPS code in order to merge with other data.
#
# We'll go ahead and add '06' for the state of California and '075' for the county of San Francisco to the census tract number as follows:

# %%
# create a complete FIPS code column before merging
tracts['FIPS'] ='06' + '075' + tracts['tractce10']

# %%
# double check that we have a new and complete FIPS code column
tracts.head()
# Out:
#   tractce10                                           geometry         FIPS
# 0    016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1    016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2    016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
# 3    016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...  06075016100
# 4    016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...  06075016000

# %% [markdown]
# Perfect, that worked! Now we merge on FIPS as follows:

# %%
# create a new dataframe based on the merge
# tracts is spatial data so it must come first
nhoods=tracts.merge(ct,on="FIPS")

# %%
nhoods.head(5)
# Out:
#   tractce10                                           geometry         FIPS  \
# 0    016500  MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1    016400  MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2    016300  MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
# 3    016100  MULTIPOLYGON (((-122.42891 37.77804, -122.4291...  06075016100
# 4    016000  MULTIPOLYGON (((-122.42042 37.78058, -122.4203...  06075016000
#
#       Shape Area       Neighborhood Census Tract   Shape Length  \
# 0  3986994.21363  Lone Mountain/USF       016500  9798.02524207
# 1  3326589.16121       Hayes Valley       016400  7589.67939621
# 2  2646081.50418       Hayes Valley       016300  6603.94140199
# 3  3970258.84056   Western Addition       016100   8525.8087554
# 4  1702990.14508   Western Addition       016000  5942.83554773
#
#                                             Geometry
# 0  MULTIPOLYGON (((-122.44092 37.77363, -122.4425...
# ...

# %%
# define the columns to keep, which include: geometry, FIPS and Neighborhood
columns_to_keep = ['geometry',
                   'FIPS',
                   'Neighborhood']

# %%
# copy and create a new function, nhoods2, that just displays the defined columns to keep
nhoods2 = nhoods[columns_to_keep].copy()
nhoods2
# Out:
#                                               geometry         FIPS  \
# 0    MULTIPOLYGON (((-122.44647 37.77580, -122.4447...  06075016500
# 1    MULTIPOLYGON (((-122.44034 37.77658, -122.4398...  06075016400
# 2    MULTIPOLYGON (((-122.42915 37.77801, -122.4289...  06075016300
# 3    MULTIPOLYGON (((-122.42891 37.77804, -122.4291...  06075016100
# 4    MULTIPOLYGON (((-122.42042 37.78058, -122.4203...  06075016000
# ..                                                 ...          ...
# 190  MULTIPOLYGON (((-122.40716 37.77974, -122.4076...  06075017601
# 191  MULTIPOLYGON (((-122.44257 37.76593, -122.4423...  06075017000
# 192  MULTIPOLYGON (((-122.42695 37.76917, -122.4274...  06075016900
# 193  MULTIPOLYGON (((-122.43930 37.76817, -122.4401...  06075016700
# 194  MULTIPOLYGON (((-122.44055 37.77178, -122.4403...  06075016600
#
#             Neighborhood
# 0      Lone Mountain/USF
# 1           Hayes Valley
# 2           Hayes Valley
# 3       Western Addition
# ...

# %% [markdown]
# This is exactly what we need in order to start contextualizing and mapping our 195 census tracts by larger neighborhood groups!
#
# In the next section, we'll experiment with a few different types of static and interactive mapping techniques that will inform how we visualize our data throughout the rest of our project.

# %% [markdown]
# ### Applying Neighborhood Boundaries: Mapping & Visualizations

# %%
#simple plot map with random colors, corresponding to different neighborhoods
nhoods.plot(column='Neighborhood')
# Out:
# <AxesSubplot: >

# %%
# a slightly more advanced and visually appealing map with its axis turned off and a more defined figure size
ax1 = nhoods2.plot(
        column='Neighborhood', 
        figsize=(12,8),
        cmap='PuBuGn',
        )
ax1.axis('off')
# Out:
# (-122.5467034, -122.2691646, 37.69699805, 37.940910949999996)

# %%
# importing library
import matplotlib.pyplot as plt

# %%
# Making another non-interactive figure with axis turned off and a new title at the top
fig, ax = plt.subplots(figsize = (12,10)) 
nhoods2.plot(column = 'Neighborhood',legend=False,
  edgecolor='white',cmap = 'PuBuGn',ax=ax)
ax.axis('off')
plt.title('San Francisco Neighborhoods by Census Tract (2010)')
# Out:
# Text(0.5, 1.0, 'San Francisco Neighborhoods by Census Tract (2010)')

# %%
# trying out a new interactive map! 
# as you hover over each census tract, a pop-up shows the neighborhood that it exists within
nhoods2.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# making the interactive map a bit prettier and easier to interpret, and adding a neighborhood legend
nhoods2.explore(
     column="Neighborhood", # make choropleth based on "BoroName" column
     popup=True, # show all values in popup (on click)
     tiles="cartodbpositron", # use "CartoDB positron" tiles
     cmap="PuBuGn", # use "Set1" matplotlib colormap
     style_kwds=dict(color="white") # use black outline
    )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
