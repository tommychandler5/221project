# %% [markdown]
# ## San Francisco: From (2020) Census Tracts to Neighborhoods
# ### Team Code & Cry
#
# In order to effectively analyze and compare our data and calculated health indicators - much of which is collected at the census tract level - we decided to work at the neighborhood level, as this is a more effective scale for storytelling and visualizations. In order to do so, we used the [Analysis Neighborhoods data set](https://data.sfgov.org/Geographic-Locations-and-Boundaries/Analysis-Neighborhoods-2020-census-tracts-assigned/sevw-6tgi) from DataSF. These neighborhood boundaries and their respective census tracts were created by the Department of Public Health and the Mayor's Office of Housing & Community Development, with support from the Planning Department.
#
# The data set included neighborhoods comprised of 2020 census tracts, using common real estate and residents’ definitions for the purpose of providing consistency in the analysis and reporting of socio-economic, demographic, and environmental data. Note that these so-called 'analysis neighborhoods' are not codified in Planning Code nor Administrative Code, but they provide a consistent and shared definition of neighborhood boundaries throughout the entirety of our project.

# %% [markdown]
# ### Analysis Neighborhoods

# %%
#importing libraries
import pandas as pd
import geopandas as gpd
import plotly.express as px

# %%
#pull in the Analysis Neighborhoods data set from DataSF
ct = gpd.read_file('data/SF2020_Neighborhoods_CTs.geojson')

# %%
ct.shape
# Out:
# (242, 12)

# %% [markdown]
# Looks like their are 242 census tracts in this file, all of which are assigned to one of the neighborhoods. Let's dig a bit deeper and see what the data looks like, and how neighborhoods and census tracts are marked:

# %%
ct.head()
# Out:
#       name neighborhoods_analysis_boundaries tractce sup_dist_2022  \
# 0     9809             Bayview Hunters Point  980900            10
# 1     9806             Bayview Hunters Point  980600            10
# 2  9805.01                      McLaren Park  980501            10
# 3  9804.01                    The Farallones  980401             4
# 4      612             Bayview Hunters Point  061200            10
#
#        data_loaded_at county_fp state_fp sup_dist_2012  \
# 0 2022-07-08 14:12:00       075       06            10
# 1 2022-07-08 14:12:00       075       06            10
# 2 2022-07-08 14:12:00       075       06            10
# 3 2022-07-08 14:12:00       075       06             1
# 4 2022-07-08 14:12:00       075       06            10
#
#                data_as_of object_id        geoid  \
# 0 2022-07-08 21:09:48.141       242  06075980900
# 1 2022-07-08 21:09:48.141       241  06075980600
# 2 2022-07-08 21:09:48.141       240  06075980501
# ...

# %% [markdown]
# Great, this is the exact data we need in order to merge other datasets and assign census tracts to larger neighborhoods. Let's clean this data set up a bit though, by renaming some columns:

# %%
#renaming the six columns
ct.columns = ['Name',
              'Neighborhood', 
              'Census Tract',
              'Supervisor District 2022',
              'Data Loaded',
              'County Code',
              'State Code',
              'Supervisor District 2012',
              'Data as of',
              'Object ID',
              'FIPS',
              'Geometry',]

# %%
#checking that the above function worked
ct.head()
# Out:
#       Name           Neighborhood Census Tract Supervisor District 2022  \
# 0     9809  Bayview Hunters Point       980900                       10
# 1     9806  Bayview Hunters Point       980600                       10
# 2  9805.01           McLaren Park       980501                       10
# 3  9804.01         The Farallones       980401                        4
# 4      612  Bayview Hunters Point       061200                       10
#
#           Data Loaded County Code State Code Supervisor District 2012  \
# 0 2022-07-08 14:12:00         075         06                       10
# 1 2022-07-08 14:12:00         075         06                       10
# 2 2022-07-08 14:12:00         075         06                       10
# 3 2022-07-08 14:12:00         075         06                        1
# 4 2022-07-08 14:12:00         075         06                       10
#
#                Data as of Object ID        geoid  \
# 0 2022-07-08 21:09:48.141       242  06075980900
# ...

# %% [markdown]
# Perfect, now that our data is a bit more cleaned up, let's see if we can learn a bit more about the breakdown of how many census tracts are assigned to each neighborhood:

# %%
# getting a count on how many census tracts are in each neighborhood
ct['Neighborhood'].value_counts()
# Out:
# Mission                           17
# Sunset/Parkside                   16
# Tenderloin                        12
# Outer Richmond                    11
# Bayview Hunters Point             11
# Financial District/South Beach    10
# Marina                             9
# Pacific Heights                    9
# Nob Hill                           9
# Excelsior                          8
# Russian Hill                       7
# Western Addition                   7
# West of Twin Peaks                 7
# South of Market                    7
# Castro/Upper Market                7
# Chinatown                          6
# Bernal Heights                     6
# Oceanview/Merced/Ingleside         6
# Inner Sunset                       6
# Noe Valley                         6
# Hayes Valley                       5
# Haight Ashbury                     5
# Outer Mission                      5
# North Beach                        5
# Potrero Hill                       5
# ...

# %% [markdown]
# This is really interesting to see, and makes me excited to further visualize and map these neighborhoods.
# Next, we'll need to join this Analysis Neighborhoods data with our spatial data from 2020 census tracts. Then, we can finally begin mapping.

# %% [markdown]
# ### Merging Analysis Neighborhoods with Spatial Data

# %%
import geopandas as gpd

# %%
# bring in the geojson file with census tracts
tracts=gpd.read_file('data/2020CTs.geojson')
# see what the data looks like
tracts.head()
# Out:
#       name      intptlon  awater  mtfcc      aland              namelsad  \
# 0  9805.01  -122.4193463  9769.0  G5020  1471536.0  Census Tract 9805.01
# 1   171.02  -122.4504754     0.0  G5020   294894.0   Census Tract 171.02
# 2   123.02  -122.4120970     0.0  G5020    92653.0   Census Tract 123.02
# 3   168.01  -122.4290133     0.0  G5020   226534.0   Census Tract 168.01
# 4   119.02  -122.4098067     0.0  G5020    93053.0   Census Tract 119.02
#
#   tractce statefp data_loaded_at     intptlat funcstat countyfp data_as_of  \
# 0  980501      06     2022-03-04  +37.7162081        S      075 2021-02-01
# 1  017102      06     2022-03-04  +37.7654353        S      075 2021-02-01
# 2  012302      06     2022-03-04  +37.7870222        S      075 2021-02-01
# 3  016801      06     2022-03-04  +37.7713309        S      075 2021-02-01
# 4  011902      06     2022-03-04  +37.7909959        S      075 2021-02-01
#
#          geoid                                           geometry
# ...

# %%
#seeing how many rows and columns we're working with 
tracts.shape
# Out:
# (244, 15)

# %% [markdown]
# The analysis neighborhoods data set included 244 census tracts, so this is almost an exact match. But let's pull a bit more info on this data set before merging:

# %%
tracts.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            244 non-null    object
#  1   intptlon        244 non-null    object
#  2   awater          244 non-null    object
#  3   mtfcc           244 non-null    object
#  4   aland           244 non-null    object
#  5   namelsad        244 non-null    object
#  6   tractce         244 non-null    object
#  7   statefp         244 non-null    object
#  8   data_loaded_at  244 non-null    datetime64[ns]
#  9   intptlat        244 non-null    object
#  10  funcstat        244 non-null    object
#  11  countyfp        244 non-null    object
#  12  data_as_of      244 non-null    datetime64[ns]
#  13  geoid           244 non-null    object
#  14  geometry        244 non-null    geometry
# dtypes: datetime64[ns](2), geometry(1), object(12)
# memory usage: 28.7+ KB

# %% [markdown]
# Based on this list of columns, we really only need the census tract number (tractce10) and geometry columns in order to merge the two data sets. Let's move forward with doing so:

# %%
tracts = tracts[['tractce','geometry']]
tracts.head()
# Out:
#   tractce                                           geometry
# 0  980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...
# 1  017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...
# 2  012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...
# 3  016801  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...
# 4  011902  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...

# %% [markdown]
# We have the census tract number, but we need a full FIPS code to merge. We'll add '06' for the state of California and '075' for the county of San Francisco to the census tract number as follows:

# %%
# create a FIPS column before merging
tracts['FIPS'] ='06' + '075' + tracts['tractce']

# %%
# double check that we have a new and complete FIPS code column
tracts.head()
# Out:
#   tractce                                           geometry         FIPS
# 0  980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...  06075980501
# 1  017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...  06075017102
# 2  012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...  06075012302
# 3  016801  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...  06075016801
# 4  011902  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...  06075011902

# %% [markdown]
# Perfect, that worked! Now we merge on FIPS as follows:

# %%
# create a new dataframe based on the join, tracts is spatial data so must come first
nhoods=tracts.merge(ct,on="FIPS")

# %%
nhoods.head(5)
# Out:
#   tractce                                           geometry         FIPS  \
# 0  980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...  06075980501
# 1  017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...  06075017102
# 2  012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...  06075012302
# 3  016801  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...  06075016801
# 4  011902  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...  06075011902
#
#       Name    Neighborhood Census Tract Supervisor District 2022  \
# 0  9805.01    McLaren Park       980501                       10
# 1   171.02  Haight Ashbury       017102                        8
# 2   123.02      Tenderloin       012302                        3
# 3   168.01    Hayes Valley       016801                        5
# 4   119.02        Nob Hill       011902                        3
#
#           Data Loaded County Code State Code Supervisor District 2012  \
# ...

# %%
# define the columns to keep, which include: geometry, FIPS and Neighborhood
columns_to_keep = ['geometry',
                   'FIPS',
                   'Neighborhood']

# %%
# copy and create a new function, nhoods2, that just displays the defined columns to keep
nhoods2 = nhoods[columns_to_keep].copy()
nhoods2
# Out:
#                                               geometry         FIPS  \
# 0    MULTIPOLYGON (((-122.42722 37.71555, -122.4271...  06075980501
# 1    MULTIPOLYGON (((-122.45321 37.76825, -122.4516...  06075017102
# 2    MULTIPOLYGON (((-122.41500 37.78745, -122.4133...  06075012302
# 3    MULTIPOLYGON (((-122.43235 37.77378, -122.4308...  06075016801
# 4    MULTIPOLYGON (((-122.41246 37.79163, -122.4117...  06075011902
# ..                                                 ...          ...
# 237  MULTIPOLYGON (((-122.42646 37.76627, -122.4252...  06075020201
# 238  MULTIPOLYGON (((-122.39362 37.78308, -122.3928...  06075061508
# 239  MULTIPOLYGON (((-122.43075 37.79865, -122.4291...  06075013001
# 240  MULTIPOLYGON (((-122.42484 37.80227, -122.4246...  06075010201
# 241  MULTIPOLYGON (((-122.42280 37.79216, -122.4225...  06075011101
#
#                        Neighborhood
# 0                      McLaren Park
# 1                    Haight Ashbury
# 2                        Tenderloin
# ...

# %% [markdown]
# This is exactly what we need in order to start mapping our neighborhoods of census tracts! In the next section, we'll experiment with a few different types of static and interactive mapping techniques that will inform how we visualize our data, by neighborhood, throughout the rest of our project.

# %% [markdown]
# ### Mapping & Visualizations

# %%
#simple plot map with colors
nhoods.plot(column='Neighborhood')
# Out:
# <AxesSubplot: >

# %%
# a slightly more advanced, and visually appealing, map with the axis turned off and a more fidefined size
ax1 = nhoods2.plot(
        column='Neighborhood', 
        figsize=(12,10),
        cmap='PuBuGn',
        )
ax1.axis('off')
# Out:
# (-123.2161204, -122.2856216, 37.628661349999994, 37.87437165)

# %%
# importing 
import matplotlib.pyplot as plt

# %%
# Making another non-interactive figure with axis turned off and a new title at the top
fig, ax = plt.subplots(figsize = (12,10)) 
nhoods2.plot(column = 'Neighborhood',legend=False,
  edgecolor='white',cmap = 'PuBuGn',ax=ax)
ax.axis('off')
plt.title('San Francisco Neighborhoods by Census Tract')
# Out:
# Text(0.5, 1.0, 'San Francisco Neighborhoods by Census Tract')

# %%
# trying out a new interactive map! as you hover over census tracts, a pop-up shows their designated neighborhood
nhoods2.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# making the interactive map a bit prettier, and easier to understand
nhoods2.explore(
     column="Neighborhood", # make choropleth based on "BoroName" column
     tooltip="Neighborhood", # show "BoroName" value in tooltip (on hover)
     popup=True, # show all values in popup (on click)
     tiles="cartodbpositron", # use "CartoDB positron" tiles
     cmap="Set2", # use "Set1" matplotlib colormap
     style_kwds=dict(color="white") # use black outline
    )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
