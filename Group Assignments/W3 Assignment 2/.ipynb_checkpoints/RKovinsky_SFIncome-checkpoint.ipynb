# %%
import pandas as pd

# %%
# load the data
cd = pd.read_csv('data/SFMedianIncome.csv')

# %%
cd.shape
# Out:
# (244, 13)

# %%
cd.head(3)
# Out:
#          FIPS                                          Geo_QName Geo_FILEID  \
# 0  6075010101  Census Tract 101.01, San Francisco County, Cal...      ACSSF
# 1  6075010102  Census Tract 101.02, San Francisco County, Cal...      ACSSF
# 2  6075010201  Census Tract 102.01, San Francisco County, Cal...      ACSSF
#
#    Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_STATE  Geo_COUNTY  Geo_TRACT  \
# 0         140            0          9875          6          75      10101
# 1         140            0          9876          6          75      10102
# 2         140            0          9877          6          75      10201
#
#             Geo_GEOID             Geo_NAME  Geo_BTTR  Median Household Income
# 0  14000US06075010101  Census Tract 101.01       NaN                  78661.0
# 1  14000US06075010102  Census Tract 101.02       NaN                      NaN
# 2  14000US06075010201  Census Tract 102.01       NaN                 159647.0

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FIPS                     244 non-null    int64
#  1   Geo_QName                244 non-null    object
#  2   Geo_FILEID               244 non-null    object
#  3   Geo_SUMLEV               244 non-null    int64
#  4   Geo_GEOCOMP              244 non-null    int64
#  5   Geo_LOGRECNO             244 non-null    int64
#  6   Geo_STATE                244 non-null    int64
#  7   Geo_COUNTY               244 non-null    int64
#  8   Geo_TRACT                244 non-null    int64
#  9   Geo_GEOID                244 non-null    object
#  10  Geo_NAME                 244 non-null    object
#  11  Geo_BTTR                 0 non-null      float64
#  12  Median Household Income  234 non-null    float64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 24.9+ KB

# %%
cd.FIPS.head(5)
# Out:
# 0    6075010101
# 1    6075010102
# 2    6075010201
# 3    6075010202
# 4    6075010300
# Name: FIPS, dtype: int64

# %%
cd.Geo_STATE.head(3)
# Out:
# 0    6
# 1    6
# 2    6
# Name: Geo_STATE, dtype: int64

# %%
cd.Geo_COUNTY.head(3)
# Out:
# 0    75
# 1    75
# 2    75
# Name: Geo_COUNTY, dtype: int64

# %%
#re-import data
# make FIPS column a string 

cd = pd.read_csv(
    'data/SFMedianIncome.csv',
    dtype=
    {
        'FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
# double check this worked
cd.head(3)
# Out:
#           FIPS                                          Geo_QName Geo_FILEID  \
# 0  06075010101  Census Tract 101.01, San Francisco County, Cal...      ACSSF
# 1  06075010102  Census Tract 101.02, San Francisco County, Cal...      ACSSF
# 2  06075010201  Census Tract 102.01, San Francisco County, Cal...      ACSSF
#
#    Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO Geo_STATE Geo_COUNTY  Geo_TRACT  \
# 0         140            0          9875        06        075      10101
# 1         140            0          9876        06        075      10102
# 2         140            0          9877        06        075      10201
#
#             Geo_GEOID             Geo_NAME  Geo_BTTR  Median Household Income
# 0  14000US06075010101  Census Tract 101.01       NaN                  78661.0
# 1  14000US06075010102  Census Tract 101.02       NaN                      NaN
# 2  14000US06075010201  Census Tract 102.01       NaN                 159647.0

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FIPS                     244 non-null    object
#  1   Geo_QName                244 non-null    object
#  2   Geo_FILEID               244 non-null    object
#  3   Geo_SUMLEV               244 non-null    int64
#  4   Geo_GEOCOMP              244 non-null    int64
#  5   Geo_LOGRECNO             244 non-null    int64
#  6   Geo_STATE                244 non-null    object
#  7   Geo_COUNTY               244 non-null    object
#  8   Geo_TRACT                244 non-null    int64
#  9   Geo_GEOID                244 non-null    object
#  10  Geo_NAME                 244 non-null    object
#  11  Geo_BTTR                 0 non-null      float64
#  12  Median Household Income  234 non-null    float64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 24.9+ KB

# %%
cd.columns[cd.isna().all()].tolist()
# Out:
# ['Geo_BTTR']

# %%
cd = cd.dropna(axis=1,how="all")

# %%
# double checking that column was dropped correctly
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FIPS                     244 non-null    object
#  1   Geo_QName                244 non-null    object
#  2   Geo_FILEID               244 non-null    object
#  3   Geo_SUMLEV               244 non-null    int64
#  4   Geo_GEOCOMP              244 non-null    int64
#  5   Geo_LOGRECNO             244 non-null    int64
#  6   Geo_STATE                244 non-null    object
#  7   Geo_COUNTY               244 non-null    object
#  8   Geo_TRACT                244 non-null    int64
#  9   Geo_GEOID                244 non-null    object
#  10  Geo_NAME                 244 non-null    object
#  11  Median Household Income  234 non-null    float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 23.0+ KB

# %% [markdown]
# ## Deciding Which Columns to Keep

# %%
# define columns to keep
columns_to_keep = ['FIPS',
                   'Median Household Income']

# %%
# add it to a new dataframe!
cd2 = cd[columns_to_keep]

# %%
cd2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   FIPS                     244 non-null    object
#  1   Median Household Income  234 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.9+ KB

# %%
cd2.head()
# Out:
#           FIPS  Median Household Income
# 0  06075010101                  78661.0
# 1  06075010102                      NaN
# 2  06075010201                 159647.0
# 3  06075010202                 192500.0
# 4  06075010300                 136643.0

# %%
cd2.sample(4)
# Out:
#             FIPS  Median Household Income
# 224  06075061102                  24656.0
# 101  06075020601                 147091.0
# 233  06075061506                 250001.0
# 87   06075017700                 147986.0

# %%
cd2['Median Household Income'].mean()
# Out:
# 130761.42735042734

# %%
cd2['Median Household Income'].median()
# Out:
# 128668.5

# %%
# get a quick stats summary
cd2['Median Household Income'].describe()
# Out:
# count       234.00000
# mean     130761.42735
# std       54277.35169
# min       11316.00000
# 25%       95195.75000
# 50%      128668.50000
# 75%      166517.50000
# max      250001.00000
# Name: Median Household Income, dtype: float64

# %%
# plot it as a historgram with 10 bins
cd2['Median Household Income'].plot.hist(bins=10)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# now, a box plot
cd2.boxplot(column=['Median Household Income'])
# Out:
# <AxesSubplot: >

# %%
cd_sorted = cd2.sort_values(by='Median Household Income',ascending = False)

# %%
# lets display the data, but just a few of the columns to get a sense for the top 5 highest median household income census tracts
cd_sorted[['FIPS','Median Household Income']].head(5)
# Out:
#             FIPS  Median Household Income
# 228  06075061501                 250001.0
# 233  06075061506                 250001.0
# 43   06075012802                 250001.0
# 232  06075061505                 249901.0
# 119  06075022704                 247031.0

# %%
# lets see if I can get the five lowest median household income tracts to show now
cd_sorted = cd2.sort_values(by='Median Household Income',ascending = True)

# %%
cd_sorted[['FIPS','Median Household Income']].head(5)
# Out:
#             FIPS  Median Household Income
# 239  06075980501                  11316.0
# 223  06075061101                  17146.0
# 9    06075010701                  22345.0
# 70   06075016102                  22542.0
# 38   06075012504                  22671.0

# %%
# plot it
cd_sorted.head(5).plot.bar(x='FIPS',
                            y='Median Household Income')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %%
# make the bar chart look a bit better 
cd_sorted.head(5).plot.barh(x='FIPS',
                            y='Median Household Income', 
                            title='5 Census Tracts with the Lowest Household Median Income in SF 2021',
                            color='orange')
# Out:
# <AxesSubplot: title={'center': '5 Census Tracts with the Lowest Household Median Income in SF 2021'}, ylabel='FIPS'>

# %%
cd2[cd2['Median Household Income']>100000]
# Out:
#             FIPS  Median Household Income
# 2    06075010201                 159647.0
# 3    06075010202                 192500.0
# 4    06075010300                 136643.0
# 5    06075010401                 115170.0
# 6    06075010402                 176192.0
# ..           ...                      ...
# 232  06075061505                 249901.0
# 233  06075061506                 250001.0
# 237  06075980300                 149688.0
# 240  06075980600                 120268.0
# 241  06075980900                 137750.0
#
# [170 rows x 2 columns]

# %%
cd2[cd2['Median Household Income']<50000]
# Out:
#             FIPS  Median Household Income
# 9    06075010701                  22345.0
# 19   06075011300                  36382.0
# 21   06075011800                  40321.0
# 27   06075012202                  43750.0
# 30   06075012301                  26406.0
# 31   06075012302                  47807.0
# 32   06075012403                  37800.0
# 33   06075012404                  25865.0
# 35   06075012406                  30972.0
# 36   06075012502                  25754.0
# 37   06075012503                  35033.0
# 38   06075012504                  22671.0
# 69   06075016101                  23750.0
# 70   06075016102                  22542.0
# 88   06075017801                  30030.0
# 128  06075023102                  41434.0
# 129  06075023103                  27946.0
# 218  06075060502                  34896.0
# 223  06075061101                  17146.0
# 224  06075061102                  24656.0
# 239  06075980501                  11316.0

# %%
import geopandas as gpd

# %%
# read in a geojson file
tracts=gpd.read_file('data/2020SFCTs.geojson')
tracts.head()
# Out:
#       name      intptlon  awater  mtfcc      aland              namelsad  \
# 0  9805.01  -122.4193463  9769.0  G5020  1471536.0  Census Tract 9805.01
# 1   171.02  -122.4504754     0.0  G5020   294894.0   Census Tract 171.02
# 2   123.02  -122.4120970     0.0  G5020    92653.0   Census Tract 123.02
# 3   168.01  -122.4290133     0.0  G5020   226534.0   Census Tract 168.01
# 4   119.02  -122.4098067     0.0  G5020    93053.0   Census Tract 119.02
#
#   tractce statefp data_loaded_at     intptlat funcstat countyfp data_as_of  \
# 0  980501      06     2022-03-04  +37.7162081        S      075 2021-02-01
# 1  017102      06     2022-03-04  +37.7654353        S      075 2021-02-01
# 2  012302      06     2022-03-04  +37.7870222        S      075 2021-02-01
# 3  016801      06     2022-03-04  +37.7713309        S      075 2021-02-01
# 4  011902      06     2022-03-04  +37.7909959        S      075 2021-02-01
#
#          geoid                                           geometry
# 0  06075980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...
# 1  06075017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...
# 2  06075012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...
# 3  06075016801  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...
# 4  06075011902  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...

# %%
# plot it!
tracts.plot(figsize=(12,10))
# Out:
# <AxesSubplot: >

# %%
# tell me more about this dataset
tracts.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            244 non-null    object
#  1   intptlon        244 non-null    object
#  2   awater          244 non-null    object
#  3   mtfcc           244 non-null    object
#  4   aland           244 non-null    object
#  5   namelsad        244 non-null    object
#  6   tractce         244 non-null    object
#  7   statefp         244 non-null    object
#  8   data_loaded_at  244 non-null    datetime64[ns]
#  9   intptlat        244 non-null    object
#  10  funcstat        244 non-null    object
#  11  countyfp        244 non-null    object
#  12  data_as_of      244 non-null    datetime64[ns]
#  13  geoid           244 non-null    object
#  14  geometry        244 non-null    geometry
# dtypes: datetime64[ns](2), geometry(1), object(12)
# memory usage: 28.7+ KB

# %%
# I only really need FIPS and geometry, so let's subset the data
tracts = tracts[['tractce','geometry']]
tracts.head()
# Out:
#   tractce                                           geometry
# 0  980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...
# 1  017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...
# 2  012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...
# 3  016801  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...
# 4  011902  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...

# %%
# now I create a FIPS column
tracts['FIPS'] ='06' + '075' + tracts['tractce']

# %%
tracts.head()
# Out:
#   tractce                                           geometry         FIPS
# 0  980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...  06075980501
# 1  017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...  06075017102
# 2  012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...  06075012302
# 3  016801  MULTIPOLYGON (((-122.43235 37.77378, -122.4308...  06075016801
# 4  011902  MULTIPOLYGON (((-122.41246 37.79163, -122.4117...  06075011902

# %%
# create a new dataframe based on the join
tracts_income=tracts.merge(cd2,on="FIPS")

# %%
tracts_income.head(3)
# Out:
#   tractce                                           geometry         FIPS  \
# 0  980501  MULTIPOLYGON (((-122.42722 37.71555, -122.4271...  06075980501
# 1  017102  MULTIPOLYGON (((-122.45321 37.76825, -122.4516...  06075017102
# 2  012302  MULTIPOLYGON (((-122.41500 37.78745, -122.4133...  06075012302
#
#    Median Household Income
# 0                  11316.0
# 1                 174375.0
# 2                  47807.0

# %%
#generate a choropleth map based on the merged dataset 
tracts_income.plot(figsize=(12,10),
                 column='Median Household Income',
                 legend=True, 
                 scheme='equal_interval')
# Out:
# <AxesSubplot: >

# %%
import folium

# %%
m = folium.Map(location=[37.7,-122.4], 
               zoom_start = 9,
               tiles='CartoDB positron', 
               attribution='CartoDB')

# %%
# plot chorpleth over the base map
folium.Choropleth(
                  geo_data=tracts_income, # geo data
                  data=tracts_income, # data          
                  key_on='feature.properties.FIPS', # key, or merge column
                  columns=['FIPS', 'Median Household Income'], # [key, value]
                  fill_color='BuPu',
                  line_weight=0.1, 
                  fill_opacity=0.8,
                  line_opacity=0.2, # line opacity (of the border)
                  legend_name='Median Household Income (2020)').add_to(m)    # name on the legend color bar
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44c35f37d7d3f8ecc9e5e544df3ca327 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44c35f37d7d3f8ecc9e5e544df3ca327&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44c35f37d7d3f8ecc9e5e544df3ca327 = L.map(
#                 &quot;map_44c35f37d7d3f8ecc9e5e544df3ca327&quot;,
#                 {
#                     center: [37.7, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     attribution: &quot;CartoDB&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_415ba88a7b73b7cbd3b1260f485bceb4 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44c35f37d7d3f8ecc9e5e544df3ca327);
#
#
#             var choropleth_6350a54bc9ee7f659a8c6668367c05eb = L.featureGroup(
#                 {}
#             ).addTo(map_44c35f37d7d3f8ecc9e5e544df3ca327);
#
#
#         function geo_json_72c060459204c9ab0531111f88fec390_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;5&quot;: case &quot;16&quot;: case &quot;32&quot;: case &quot;36&quot;: case &quot;62&quot;: case &quot;67&quot;: case &quot;74&quot;: case &quot;76&quot;: case &quot;99&quot;: case &quot;165&quot;: case &quot;181&quot;: case &quot;202&quot;: case &quot;203&quot;: case &quot;206&quot;: case &quot;209&quot;: case &quot;211&quot;: case &quot;216&quot;: case &quot;217&quot;: case &quot;228&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#edf8fb&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;15&quot;: case &quot;45&quot;: case &quot;63&quot;: case &quot;65&quot;: case &quot;78&quot;: case &quot;92&quot;: case &quot;119&quot;: case &quot;121&quot;: case &quot;125&quot;: case &quot;128&quot;: case &quot;131&quot;: case &quot;135&quot;: case &quot;153&quot;: case &quot;157&quot;: case &quot;160&quot;: case &quot;161&quot;: case &quot;162&quot;: case &quot;168&quot;: case &quot;169&quot;: case &quot;177&quot;: case &quot;178&quot;: case &quot;179&quot;: case &quot;194&quot;: case &quot;198&quot;: case &quot;208&quot;: case &quot;233&quot;: case &quot;234&quot;: case &quot;236&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#8856a7&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;4&quot;: case &quot;9&quot;: case &quot;14&quot;: case &quot;21&quot;: case &quot;27&quot;: case &quot;31&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;59&quot;: case &quot;71&quot;: case &quot;75&quot;: case &quot;79&quot;: case &quot;86&quot;: case &quot;100&quot;: case &quot;109&quot;: case &quot;137&quot;: case &quot;143&quot;: case &quot;145&quot;: case &quot;146&quot;: case &quot;148&quot;: case &quot;149&quot;: case &quot;151&quot;: case &quot;167&quot;: case &quot;172&quot;: case &quot;184&quot;: case &quot;188&quot;: case &quot;190&quot;: case &quot;210&quot;: case &quot;221&quot;: case &quot;226&quot;: case &quot;229&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bfd3e6&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 0.1};
#                 case &quot;6&quot;: case &quot;25&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;34&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;64&quot;: case &quot;66&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;80&quot;: case &quot;83&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;93&quot;: case &quot;101&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;106&quot;: case &quot;107&quot;: case &quot;108&quot;: case &quot;111&quot;: case &quot;113&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;120&quot;: case &quot;124&quot;: case &quot;127&quot;: case &quot;130&quot;: case &quot;136&quot;: case &quot;138&quot;: case &quot;139&quot;: case &quot;140&quot;: case &quot;147&quot;: case &quot;152&quot;:
